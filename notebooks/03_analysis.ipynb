# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Linear Regression Model

# %% [markdown]
# ### Initial Feature Transformations

# %% [markdown]
# Transform numerical features on basis of a first visual impression and use one-hot-encoding for categorical features.

# %% [markdown]
# ### Model Building

# %% [markdown]
# I plan to build my model through iteration of assumption checks, hypothesis testing, feature transformations and feature selection.

# %% [markdown]
# ## Interpretation
