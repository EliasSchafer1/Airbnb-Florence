# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Hypotheses

# %% [markdown]
# Formulate a hypothesis for each variable that I chose to consider.
#
# Hypothesis of type: Positive/Negative/No relation to price is expected.

# %% [markdown]
# Evt. Listings mit mehr als 6 Schlafzimmern entfernen:

# %%
x=[i for i in range(1, 10)]
y=[df.loc[df["bedrooms"]==n, "price"].mean() for n in x]
plt.plot(x, y)

# %%
sns.boxplot(x="bedrooms", y="log_price", data=df)
